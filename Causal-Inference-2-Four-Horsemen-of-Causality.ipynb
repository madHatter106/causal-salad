# %%
import warnings
warnings.filterwarnings('ignore', category=RuntimeWarning)

import numpy as np
import pandas as pd

import pymc3 as pm
import arviz as ar
from causalgraphicalmodels import CausalGraphicalModel as CGM

# %% [markdown]
# The present post describes four principal causal patterns worth knowing to avoid spurrious correlations Simple examples follow brief descriptions illustrated with DAGs, similar to the [previous post]().
#
# 1. <u>The Pipe</u>

# %%
pipe_cgm = CGM(nodes=['A', 'B', 'C'],
              edges=[('A', 'B'), ('B', 'C')])
pipe_cgm.draw()

# %% [markdown]
# 2. <u>The Fork</u>

# %%
fork_cgm = CGM(nodes=['A', 'B', 'C'], edges=[('B', 'A'), ('B', 'C')])
fork_cgm.draw()

# %% [markdown]
# 3. <u>The Descendant</u>

# %% [markdown]
# 4. <u>The Collider</u>

# %%
collider_cgm = CGM(nodes=['A', 'B', 'C'], edges=[('A', 'B'), ('C', 'B')])
collider_cgm.draw()
